# %% [markdown]
# # Model Building

# %% [markdown]
# ### Getting Ready

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import ast
from IPython.display import display, Image
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import pickle
N_NEIGHBORS = 6

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv(r'..\datasets\dataset_with_tags.csv')
df.head()
# Out:
#                                                title  \
# 0  Between Two Fires: American Indians in the Civ...
# 1                           Fashion Sourcebook 1920s
# 2                                         Hungary 56
# 3  All-American Anarchist: Joseph A. Labadie and ...
# 4                              Les oiseaux gourmands
#
#                                     author  \
# 0                 ['Laurence M. Hauptman']
# 1  ['Charlotte Fiell', 'Emmanuelle Dirix']
# 2                        ['Andy Anderson']
# 3                 ['Carlotta R. Anderson']
# 4                        ['Jean Leveille']
#
#                                                 desc  \
# 0  Reveals that several hundred thousand Indians ...
# 1  Fashion Sourcebook - 1920s is the first book i...
# 2  The seminal history and analysis of the Hungar...
# 3  "All-American Anarchist" chronicles the life a...
# 4  Aujourdhui, loiseau nous invite  sa table, tab...
#
#                                                genre  rating  reviews  \
# 0  ['History', 'Military History', 'Civil War', '...    3.52        5
# 1  ['Couture', 'Fashion', 'Historical', 'Art', 'N...    4.51        6
# 2                            ['Politics', 'History']    4.15        2
# 3                               ['Labor', 'History']    3.83        1
# 4                                                 []    4.00        1
#
#    totalratings  pages                                                img  \
# 0            33      0  https://i.gr-assets.com/images/S/compressed.ph...
# 1            41    576  https://i.gr-assets.com/images/S/compressed.ph...
# 2            26    124  https://i.gr-assets.com/images/S/compressed.ph...
# 3             6    324  https://i.gr-assets.com/images/S/compressed.ph...
# 4             1    177  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                                 link        isbn  score  \
# 0  https://goodreads.com/book/show/1001053.Betwee...  002914180X    0.0
# 1  https://goodreads.com/book/show/10010552-fashi...  1906863482    0.0
# 2  https://goodreads.com/book/show/1001077.Hungar...   948984147    0.0
# 3  https://goodreads.com/book/show/1001079.All_Am...   814327079    0.0
# 4  https://goodreads.com/book/show/10010880-les-o...  2761920813    0.0
#
#                                                 tags
# 0  laurencem.hauptman history militaryhistory civ...
# 1  charlottefiell emmanuelledirix couture fashion...
# 2  andyanderson politics history the seminal hist...
# 3  carlottar.anderson labor history  all american...
# 4  jeanleveille  aujourdhui loiseau nous invite s...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87687 entries, 0 to 87686
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         87687 non-null  object
#  1   author        87687 non-null  object
#  2   desc          87687 non-null  object
#  3   genre         87687 non-null  object
#  4   rating        87687 non-null  float64
#  5   reviews       87687 non-null  int64
#  6   totalratings  87687 non-null  int64
#  7   pages         87687 non-null  int64
#  8   img           87687 non-null  object
#  9   link          87687 non-null  object
#  10  isbn          87687 non-null  object
#  11  score         87687 non-null  float64
#  12  tags          87687 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 8.7+ MB

# %% [markdown]
# Function taken from [eda.ipynb](./eda.ipynb)

# %%
def display_books_info(books: pd.DataFrame) -> None:
    """
    Takes a `books` dataframe and displays each book's title, author, link and image.
    """
    for index, row in books.iterrows():
        print(f"Title: {row['title']}")
        if type(row['author']) == list:
            print(f"Author: {", ".join(row['author'])}")
        else:
            print(f"Author: {", ".join(ast.literal_eval(row['author']))}")
        print(f"Pages: {row['pages']}")
        print(f"Link: {row['link']}")
        display(Image(url=row['img'], width=200, height=300))
        print("\n")

# %% [markdown]
# ### Approach 1. `TfidfVectorizer` + `NearestNeighbors`

# %% [markdown]
# Initialize `TfidfVectorizer`

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %% [markdown]
# Vectorize the `tags` column

# %%
tfidf_matrix = vectorizer.fit_transform(df['tags'])

# %% [markdown]
# Initialize `NearestNeighbors` and fit the vector matrix

# %%
model = NearestNeighbors(n_neighbors=N_NEIGHBORS, metric='cosine')
model.fit(tfidf_matrix)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=6)

# %% [markdown]
# Create `pandas.Series` for fast index and title lookup

# %%
title2index = pd.Series(df.index, index=df['title'].str.lower())
index2title = pd.Series(df['title'], index=df.index)

# %% [markdown]
# Save all objects

# %%
with open('../models/tfidf_matrix.pkl', 'wb') as f:
    pickle.dump(tfidf_matrix, f)

with open('../models/model.pkl', 'wb') as f:
    pickle.dump(model, f)

with open('../models/title2index.pkl', 'wb') as f:
    pickle.dump(title2index, f)

with open('../models/index2title.pkl', 'wb') as f:
    pickle.dump(index2title, f)

# %% [markdown]
# Main `recommend` function

# %%
def recommend(title: str, model: NearestNeighbors=model):
    idx = title2index[title.lower()]
    distances, indices = model.kneighbors(tfidf_matrix[idx])
    indices = indices[0][1:]
    return index2title.iloc[indices]

# %%
recommend('a game of thrones').index
# Out:
# Index([7864, 28138, 44282, 37902, 66741], dtype='int64')

# %%
df[df['score'] > 0.2].sample(1)
# Out:
#             title               author  \
# 14606  Steve Jobs  ['Walter Isaacson']
#
#                                                     desc  \
# 14606  Walter Isaacson's "enthralling" (The New Yorke...
#
#                                                    genre  rating  reviews  \
# 14606  ['Biography', 'Nonfiction', 'Business', 'Scien...    4.14    19077
#
#        totalratings  pages                                                img  \
# 14606       1026052    627  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                                     link        isbn  score  \
# 14606  https://goodreads.com/book/show/11084145-steve...  1451648537  0.265
#
#                                                     tags
# 14606  walterisaacson biography nonfiction business s...

# %%
display_books_info(df[df['title'].str.lower() == 'Steve Jobs'.lower()])
# Out:
# Title: Steve Jobs
# Author: Walter Isaacson
# Pages: 627
# Link: https://goodreads.com/book/show/11084145-steve-jobs
# <img src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1511288482l/11084145._SY475_.jpg" width="200" height="300"/>

# %%
display_books_info(df.iloc[recommend('Steve Jobs').index])
# Out:
# Title: I, Steve: Steve Jobs In His Own Words
# Author: George Beahm
# Pages: 160
# Link: https://goodreads.com/book/show/12634780-i-steve
# <img src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1357641830l/12634780.jpg" width="200" height="300"/>
# Title: Leading Apple with Steve Jobs: Management Lessons from a Controversial Genius
# Author: Jay Elliot
# Pages: 192
# Link: https://goodreads.com/book/show/13839025-leading-apple-with-steve-jobs
# <img src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1349062279l/13839025.jpg" width="200" height="300"/>
# Title: The Steve Jobs Way: iLeadership for a New Generation
# Author: Jay Elliot, William L. Simon
# Pages: 0
# Link: https://goodreads.com/book/show/10589332-the-steve-jobs-way
# <img src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1348771444l/10589332.jpg" width="200" height="300"/>
# Title: Einstein: His Life and Universe
# Author: Walter Isaacson
# Pages: 675
# Link: https://goodreads.com/book/show/10884.Einstein
# <img src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1328011405l/10884.jpg" width="200" height="300"/>
# Title: The Zen of Steve Jobs
# Author: Caleb Melby, JESS3
# Pages: 80
# Link: https://goodreads.com/book/show/13078116-the-zen-of-steve-jobs
# <img src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1342498084l/13078116.jpg" width="200" height="300"/>
