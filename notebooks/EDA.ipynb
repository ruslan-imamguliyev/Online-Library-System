# %% [markdown]
# ### Exploratory Data Analysis
# Importing libraries

# %%
import pandas as pd
import numpy as np
import glob
import ast

# %%
main_df = pd.read_csv('../datasets/Books.csv')
main_df.head()
# Out:
# C:\Users\Ruslan\AppData\Local\Temp\ipykernel_20084\1811083836.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_df = pd.read_csv('../datasets/Books.csv')
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# ...

# %%
main_df[main_df['Book-Title'].duplicated()].groupby('Book-Title').size().sort_values(ascending=False).head(10)
# Out:
# Book-Title
# Selected Poems                    26
# Little Women                      23
# Wuthering Heights                 20
# Dracula                           19
# Adventures of Huckleberry Finn    19
# The Secret Garden                 19
# Jane Eyre                         18
# The Night Before Christmas        17
# Pride and Prejudice               17
# Great Expectations                16
# dtype: int64

# %%
main_df[main_df['Book-Title'] == 'Dracula']
# Out:
#               ISBN Book-Title       Book-Author Year-Of-Publication  \
# 2959    156619301X    Dracula       Bram Stoker                1994
# 5332    055321148X    Dracula       Bram Stoker                1983
# 12753   9875021245    Dracula       Bram Stoker                2004
# 12988   0140052801    Dracula       Bram Stoker                1992
# 52115   0451175816    Dracula       Bram Stoker                1992
# 61616   0880299010    Dracula       Bram Stoker                1992
# 68981   8481301183    Dracula      Bram Stocker                2001
# 72472   1562542621    Dracula  Emily Hutchinson                1998
# 82829   0515053473    Dracula       Bram Stoker                1979
# 92499   0863221432    Dracula       Bram Stoker                1992
# 106662  0453007864    Dracula       Bram Stoker                1992
# 110050  0439101344    Dracula       Bram Stoker                2001
# 116080  8401492009    Dracula       Bram Stoker                1993
# ...

# %%
main_df.drop(columns=['Publisher'], inplace=True)

# %%
main_df.drop_duplicates(subset=['Book-Title'], inplace=True)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242135 entries, 0 to 271359
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 242135 non-null  object
#  1   Book-Title           242135 non-null  object
#  2   Book-Author          242133 non-null  object
#  3   Year-Of-Publication  242135 non-null  object
#  4   Image-URL-S          242135 non-null  object
#  5   Image-URL-M          242135 non-null  object
#  6   Image-URL-L          242132 non-null  object
# dtypes: object(7)
# memory usage: 14.8+ MB

# %%
main_df.dropna(inplace=True)
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242130 entries, 0 to 271359
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 242130 non-null  object
#  1   Book-Title           242130 non-null  object
#  2   Book-Author          242130 non-null  object
#  3   Year-Of-Publication  242130 non-null  object
#  4   Image-URL-S          242130 non-null  object
#  5   Image-URL-M          242130 non-null  object
#  6   Image-URL-L          242130 non-null  object
# dtypes: object(7)
# memory usage: 14.8+ MB

# %%
main_df.nunique()
# Out:
# ISBN                   242130
# Book-Title             242130
# Book-Author             99682
# Year-Of-Publication       190
# Image-URL-S            242129
# Image-URL-M            242129
# Image-URL-L            242129
# dtype: int64

# %%
main_df.describe(include='all')
# Out:
#               ISBN           Book-Title          Book-Author  \
# count       242130               242130               242130
# unique      242130               242130                99682
# top     0195153448  Classical Mythology  William Shakespeare
# freq             1                    1                  491
#
#         Year-Of-Publication  \
# count                242130
# unique                  190
# top                    2002
# freq                  12507
#
#                                               Image-URL-S  \
# count                                              242130
# unique                                             242129
# top     http://images.amazon.com/images/P/051513628X.0...
# freq                                                    2
#
#                                               Image-URL-M  \
# count                                              242130
# unique                                             242129
# ...

# %%
main_df = main_df[main_df['Book-Author'] != 'Not Applicable (Na )']
main_df['Book-Author'].value_counts().head(10)
# Out:
# Book-Author
# William Shakespeare    491
# Agatha Christie        467
# Ann M. Martin          390
# Carolyn Keene          371
# Francine Pascal        339
# Stephen King           327
# Barbara Cartland       292
# Isaac Asimov           278
# R. L. Stine            276
# Nora Roberts           262
# Name: count, dtype: int64

# %%
main_df['Book-Author'].value_counts().sum()
# Out:
# np.int64(241854)

# %% [markdown]
# ---

# %%
df = pd.read_parquet('../datasets/0000.parquet')
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
# 1  https://www.goodreads.com/book/show/4089333-au...
# 2  https://www.goodreads.com/book/show/26764878-m...
# 3  https://www.goodreads.com/book/show/23656944-z...
# 4  https://www.goodreads.com/book/show/26761586-t...
#
#                                         id  \
# 0  1047836.Horror_Film_Directors_1931_1990
# 1        4089333-australian-urban-planning
# 2             26764878-morgen-ohne-gestern
# 3    23656944-zen-and-the-art-of-recording
# 4       26761586-the-big-book-of-codewords
#
#                                                 name               author  \
# 0                   Horror Film Directors, 1931-1990   ["Dennis Fischer"]
# 1  Australian Urban Planning: New Challenges, New...  ["Brendan Gleeson"]
# 2                         Morgen ohne gestern: Roman   ["Regina Nössler"]
# 3                       Zen and the Art of Recording         ["Mixerman"]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390000 entries, 0 to 389999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   url                390000 non-null  object
#  1   id                 390000 non-null  object
#  2   name               390000 non-null  object
#  3   author             389995 non-null  object
#  4   star_rating        390000 non-null  float64
#  5   num_ratings        390000 non-null  int64
#  6   num_reviews        193540 non-null  float64
#  7   summary            349616 non-null  object
#  8   genres             106746 non-null  object
#  9   first_published    376022 non-null  object
#  10  about_author       390000 non-null  object
#  11  community_reviews  390000 non-null  object
#  12  kindle_price       139476 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 38.7+ MB

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
# 1  https://www.goodreads.com/book/show/4089333-au...
# 2  https://www.goodreads.com/book/show/26764878-m...
# 3  https://www.goodreads.com/book/show/23656944-z...
# 4  https://www.goodreads.com/book/show/26761586-t...
#
#                                         id  \
# 0  1047836.Horror_Film_Directors_1931_1990
# 1        4089333-australian-urban-planning
# 2             26764878-morgen-ohne-gestern
# 3    23656944-zen-and-the-art-of-recording
# 4       26761586-the-big-book-of-codewords
#
#                                                 name               author  \
# 0                   Horror Film Directors, 1931-1990   ["Dennis Fischer"]
# 1  Australian Urban Planning: New Challenges, New...  ["Brendan Gleeson"]
# 2                         Morgen ohne gestern: Roman   ["Regina Nössler"]
# 3                       Zen and the Art of Recording         ["Mixerman"]
# ...

# %%
df.drop_duplicates(subset=['name'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380291 entries, 0 to 389999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   url                380291 non-null  object
#  1   id                 380291 non-null  object
#  2   name               380291 non-null  object
#  3   author             380286 non-null  object
#  4   star_rating        380291 non-null  float64
#  5   num_ratings        380291 non-null  int64
#  6   num_reviews        187208 non-null  float64
#  7   summary            340503 non-null  object
#  8   genres             102820 non-null  object
#  9   first_published    366603 non-null  object
#  10  about_author       380291 non-null  object
#  11  community_reviews  380291 non-null  object
#  12  kindle_price       135118 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 40.6+ MB

# %%
df['author'].dropna(inplace=True)

# %%
df['summary'].dropna(inplace=True)

# %%
df.dropna(subset=['author', 'summary'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 340499 entries, 0 to 389999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   url                340499 non-null  object
#  1   id                 340499 non-null  object
#  2   name               340499 non-null  object
#  3   author             340499 non-null  object
#  4   star_rating        340499 non-null  float64
#  5   num_ratings        340499 non-null  int64
#  6   num_reviews        175012 non-null  float64
#  7   summary            340499 non-null  object
#  8   genres             98826 non-null   object
#  9   first_published    334732 non-null  object
#  10  about_author       340499 non-null  object
#  11  community_reviews  340499 non-null  object
#  12  kindle_price       134408 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 36.4+ MB

# %%
df['author'] = df['author'].apply(lambda x: ast.literal_eval(x)[0])
df['author'].head()
# Out:
# 0     Dennis Fischer
# 1    Brendan Gleeson
# 2     Regina Nössler
# 3           Mixerman
# 4     Parragon Books
# Name: author, dtype: object

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
# 1  https://www.goodreads.com/book/show/4089333-au...
# 2  https://www.goodreads.com/book/show/26764878-m...
# 3  https://www.goodreads.com/book/show/23656944-z...
# 4  https://www.goodreads.com/book/show/26761586-t...
#
#                                         id  \
# 0  1047836.Horror_Film_Directors_1931_1990
# 1        4089333-australian-urban-planning
# 2             26764878-morgen-ohne-gestern
# 3    23656944-zen-and-the-art-of-recording
# 4       26761586-the-big-book-of-codewords
#
#                                                 name           author  \
# 0                   Horror Film Directors, 1931-1990   Dennis Fischer
# 1  Australian Urban Planning: New Challenges, New...  Brendan Gleeson
# 2                         Morgen ohne gestern: Roman   Regina Nössler
# 3                       Zen and the Art of Recording         Mixerman
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 340499 entries, 0 to 389999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   url                340499 non-null  object
#  1   id                 340499 non-null  object
#  2   name               340499 non-null  object
#  3   author             340499 non-null  object
#  4   star_rating        340499 non-null  float64
#  5   num_ratings        340499 non-null  int64
#  6   num_reviews        175012 non-null  float64
#  7   summary            340499 non-null  object
#  8   genres             98826 non-null   object
#  9   first_published    334732 non-null  object
#  10  about_author       340499 non-null  object
#  11  community_reviews  340499 non-null  object
#  12  kindle_price       134408 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 36.4+ MB

# %%
df['author'].value_counts().head(30)
# Out:
# author
# Various                        717
# Anonymous                      509
# Source Wikipedia               505
# Unknown                        364
# Walt Disney Company            331
# BookRags                       278
# Books LLC                      259
# Hephaestus Books               170
# Hal Leonard Corporation        115
# Parragon Books                 113
# Charles River Editors          108
# D.K. Publishing                 99
# Jesse Russell                   96
# Reader's Digest Association     93
# Brian Michael Bendis            90
# Stan Lee                        87
# Anton Chekhov                   80
# Golden Books                    77
# William Shakespeare             73
# Frederic P.  Miller             72
# Enid Blyton                     71
# Arthur Conan Doyle              70
# Scholastic Inc.                 70
# Peter David                     70
# Charles Dickens                 69
# Lonely Planet                   68
# ...

# %%
df['Book-Author'] = df['author']
df.drop(columns=['author'], inplace=True)
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
# 1  https://www.goodreads.com/book/show/4089333-au...
# 2  https://www.goodreads.com/book/show/26764878-m...
# 3  https://www.goodreads.com/book/show/23656944-z...
# 4  https://www.goodreads.com/book/show/26761586-t...
#
#                                         id  \
# 0  1047836.Horror_Film_Directors_1931_1990
# 1        4089333-australian-urban-planning
# 2             26764878-morgen-ohne-gestern
# 3    23656944-zen-and-the-art-of-recording
# 4       26761586-the-big-book-of-codewords
#
#                                                 name  star_rating  \
# 0                   Horror Film Directors, 1931-1990         4.29
# 1  Australian Urban Planning: New Challenges, New...         3.00
# 2                         Morgen ohne gestern: Roman         3.00
# 3                       Zen and the Art of Recording         4.19
# ...

# %%
df['Book-Title'] = df['name']
df.drop(columns=['name'], inplace=True)
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
# 1  https://www.goodreads.com/book/show/4089333-au...
# 2  https://www.goodreads.com/book/show/26764878-m...
# 3  https://www.goodreads.com/book/show/23656944-z...
# 4  https://www.goodreads.com/book/show/26761586-t...
#
#                                         id  star_rating  num_ratings  \
# 0  1047836.Horror_Film_Directors_1931_1990         4.29            7
# 1        4089333-australian-urban-planning         3.00            1
# 2             26764878-morgen-ohne-gestern         3.00            2
# 3    23656944-zen-and-the-art-of-recording         4.19           88
# 4       26761586-the-big-book-of-codewords         4.50            6
#
#    num_reviews                                            summary  \
# 0          NaN  An exhaustive study of the major directors of ...
# 1          NaN  Designed for use by academics, students, plann...
# ...

# %%
df.head(1)
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...
#
#                                         id  star_rating  num_ratings  \
# 0  1047836.Horror_Film_Directors_1931_1990         4.29            7
#
#    num_reviews                                            summary genres  \
# 0          NaN  An exhaustive study of the major directors of ...   None
#
#   first_published                              about_author  \
# 0       11/1/1991  {"name":"Dennis Fischer","num_books":14}
#
#                                    community_reviews kindle_price  \
# 0  {"1_stars":{"reviews_num":0,"reviews_percentag...         None
#
#       Book-Author                        Book-Title
# 0  Dennis Fischer  Horror Film Directors, 1931-1990

# %%
df = df.loc[:, ['Book-Title', 'Book-Author', 'summary', 'url', 'genres', 'star_rating', 'num_ratings']]
df.head()
# Out:
#                                           Book-Title      Book-Author  \
# 0                   Horror Film Directors, 1931-1990   Dennis Fischer
# 1  Australian Urban Planning: New Challenges, New...  Brendan Gleeson
# 2                         Morgen ohne gestern: Roman   Regina Nössler
# 3                       Zen and the Art of Recording         Mixerman
# 4                          The Big Book Of Codewords   Parragon Books
#
#                                              summary  \
# 0  An exhaustive study of the major directors of ...
# 1  Designed for use by academics, students, plann...
# 2  Christine Hoffmann wacht eines Morgens im Kran...
# 3  In this book, the third in the Zen and the Art...
# 4            500 codeword puzzles in one great book!
#
#                                                  url                  genres  \
# 0  https://www.goodreads.com/book/show/1047836.Ho...                    None
# ...

# %%
main_df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication  \
# 0    Mark P. O. Morford                2002
# 1  Richard Bruce Wright                2001
# 2          Carlo D'Este                1991
# 3      Gina Bari Kolata                1999
# 4       E. J. W. Barber                1999
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# ...

# %%
main_df[main_df['Book-Title'].str.contains('Harry Potter')].head(10)
# Out:
#              ISBN                                         Book-Title  \
# 821    0767908473  The Sorcerer's Companion: A Guide to the Magic...
# 2143   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 2809   0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 3459   0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 3839   0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 5431   0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 5506   043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 12075  207054351X                    Harry Potter Et LA Coupe De Feu
# 17559  1578564719        What's a Christian to Do with Harry Potter?
# 20166  0439625602  Harry Potter and the Prisoner of Azkaban Color...
#
#               Book-Author Year-Of-Publication  \
# 821    ALLAN ZOLA KRONZEK                2001
# 2143        J. K. Rowling                1999
# 2809        J. K. Rowling                1998
# ...

# %%
merged = pd.merge(main_df, df, on=['Book-Title', 'Book-Author'], how='inner')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3533 entries, 0 to 3532
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 3533 non-null   object
#  1   Book-Title           3533 non-null   object
#  2   Book-Author          3533 non-null   object
#  3   Year-Of-Publication  3533 non-null   object
#  4   Image-URL-S          3533 non-null   object
#  5   Image-URL-M          3533 non-null   object
#  6   Image-URL-L          3533 non-null   object
#  7   summary              3533 non-null   object
#  8   url                  3533 non-null   object
#  9   genres               2695 non-null   object
#  10  star_rating          3533 non-null   float64
#  11  num_ratings          3533 non-null   int64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 331.3+ KB
